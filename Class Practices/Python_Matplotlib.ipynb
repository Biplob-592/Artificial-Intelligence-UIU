# %% [markdown]
# **What is Matplotlib?**
#
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.

# %% [markdown]
# Most of the Matplotlib utilities lies under the **pyplot** submodule, and are usually imported under the plt alias

# %% [markdown]
# **Plotting x and y points**
#
# The plot() function is used to draw points in a diagram. By default, the plot() function draws a line from point to point.
#
#
#
# *   Parameter 1 is an array containing the points on **x-axis**
# *   Parameter 2 is an array containing the points on **y-axis**

# %% [markdown]
# **Plotting without line**

# %% [markdown]
# Default X-points [0, 1, 2, 3, ...]

# %% [markdown]
# Markers
# ![Screenshot 2025-07-30 041015.png](data:image/png;base64,...)

# %% [markdown]
# **Format Strings**
#
# You can also use the shortcut string notation parameter to specify the marker.
#
# **marker|line|color**
#
#
# ![Screenshot 2025-07-30 041337.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Multiple Lines**

# %% [markdown]
# **Create Labels and a Title for a Plot**

# %% [markdown]
# **Display Multiple Plots**

# %% [markdown]
# Creating Scatter Plots

# %% [markdown]
# Bar Plot

# %% [markdown]
# **Pie Chart**
